# %% [markdown]
# <a href="https://colab.research.google.com/github/MishraShardendu22/Deep-Learning-ANN-Project-Implementation/blob/main/Deep_Learning_Basic_Implementation_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
