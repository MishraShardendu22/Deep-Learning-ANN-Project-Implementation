# %% [markdown]
# <a href="https://colab.research.google.com/github/MishraShardendu22/Deep-Learning-ANN-Project-Implementation/blob/main/ANN_Deep_Learning_Project_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings("ignore")
